# %% [markdown]
# <a href="https://colab.research.google.com/github/lavanyamudaliyar/Machine-Learning/blob/master/Encoding(Titanic%20dataset).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df= pd.read_csv('titanic.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0              1         0       3  ...   7.2500   NaN         S
# 1              2         1       1  ...  71.2833   C85         C
# 2              3         1       3  ...   7.9250   NaN         S
# 3              4         1       1  ...  53.1000  C123         S
# 4              5         0       3  ...   8.0500   NaN         S
# ..           ...       ...     ...  ...      ...   ...       ...
# 886          887         0       2  ...  13.0000   NaN         S
# 887          888         1       1  ...  30.0000   B42         S
# 888          889         0       3  ...  23.4500   NaN         S
# 889          890         1       1  ...  30.0000  C148         C
# 890          891         0       3  ...   7.7500   NaN         Q
#
# [891 rows x 12 columns]

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500   NaN         S
# 1            2         1       1  ...  71.2833   C85         C
# 2            3         1       3  ...   7.9250   NaN         S
# 3            4         1       1  ...  53.1000  C123         S
# 4            5         0       3  ...   8.0500   NaN         S
#
# [5 rows x 12 columns]

# %%
X= df.select_dtypes(include= [object])

# %%
X.head(3)
X.dropna()
# Out:
#                                                   Name  ... Embarked
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  ...        C
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  ...        S
# 6                              McCarthy, Mr. Timothy J  ...        S
# 10                     Sandstrom, Miss. Marguerite Rut  ...        S
# 11                            Bonnell, Miss. Elizabeth  ...        S
# ..                                                 ...  ...      ...
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  ...        S
# 872                           Carlsson, Mr. Frans Olof  ...        S
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  ...        C
# 887                       Graham, Miss. Margaret Edith  ...        S
# 889                              Behr, Mr. Karl Howell  ...        C
#
# [202 rows x 5 columns]

# %%
columns= X.columns
columns
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
from sklearn import preprocessing
le= preprocessing.LabelEncoder() #encode labels with values between 0 and n_classes-1

# %%
x_2= X.apply(le.fit_transform)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_label.py in _encode(values, uniques, encode, check_unknown)
#     111         try:
# --> 112             res = _encode_python(values, uniques, encode)
#     113         except TypeError:
#
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_label.py in _encode_python(values, uniques, encode)
#      59     if uniques is None:
# ---> 60         uniques = sorted(set(values))
#      61         uniques = np.array(uniques, dtype=values.dtype)
#
# TypeError: '<' not supported between instances of 'str' and 'float'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-8dde81188591> in <module>()
# ----> 1 x_2= X.apply(le.fit_transform)
#
# ...

# %%
list(le.classes_)
# Out:
# ['110152',
#  '110413',
#  '110465',
#  '110564',
#  '110813',
#  '111240',
#  '111320',
#  '111361',
#  '111369',
#  '111426',
#  '111427',
#  '111428',
#  '112050',
#  '112052',
#  '112053',
#  '112058',
#  '112059',
#  '112277',
#  '112379',
#  '113028',
#  '113043',
#  '113050',
#  '113051',
#  '113055',
#  '113056',
#  '113059',
#  '113501',
#  '113503',
#  '113505',
#  '113509',
#  '113510',
#  '113514',
#  '113572',
#  '113760',
#  '113767',
#  '113773',
#  '113776',
#  '113781',
#  '113783',
#  '113784',
#  '113786',
#  '113787',
#  '113788',
#  '113789',
#  '113792',
#  '113794',
#  '113796',
#  '113798',
#  '113800',
#  '113803',
#  '113804',
#  '113806',
#  '113807',
#  '11668',
#  '11751',
#  '11752',
#  '11753',
#  '11755',
#  '11765',
#  '11767',
#  '11769',
#  '11771',
#  '11774',
#  '11813',
#  '11967',
#  '12233',
#  '12460',
#  '12749',
#  '13049',
#  '13213',
#  '13214',
#  '13502',
#  '13507',
#  '13509',
#  '13567',
#  '13568',
#  '14311',
#  '14312',
# ...

# %%
X.dropna()
# Out:
#                                                   Name  ... Embarked
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  ...        C
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  ...        S
# 6                              McCarthy, Mr. Timothy J  ...        S
# 10                     Sandstrom, Miss. Marguerite Rut  ...        S
# 11                            Bonnell, Miss. Elizabeth  ...        S
# ..                                                 ...  ...      ...
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  ...        S
# 872                           Carlsson, Mr. Frans Olof  ...        S
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  ...        C
# 887                       Graham, Miss. Margaret Edith  ...        S
# 889                              Behr, Mr. Karl Howell  ...        C
#
# [202 rows x 5 columns]

# %%
le.fit_transform(X['Embarked'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_label.py in _encode(values, uniques, encode, check_unknown)
#     111         try:
# --> 112             res = _encode_python(values, uniques, encode)
#     113         except TypeError:
#
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_label.py in _encode_python(values, uniques, encode)
#      59     if uniques is None:
# ---> 60         uniques = sorted(set(values))
#      61         uniques = np.array(uniques, dtype=values.dtype)
#
# TypeError: '<' not supported between instances of 'str' and 'float'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-1c1e11b478cf> in <module>()
# ----> 1 le.fit_transform(X['Embarked'])
#
# ...
